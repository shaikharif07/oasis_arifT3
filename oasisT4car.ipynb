# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# path to the training dataset
data_path = 'C:\\Users\\arif shaikh\\Downloads\\oasis\\task3\\CarPrice.csv'
car = pd.read_csv(data_path)

# %%
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
car.shape
# Out:
# (205, 26)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
car.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
car.select_dtypes(include=['int', 'float64']).columns
# Out:
# Index(['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
car.select_dtypes(include=['object']).columns
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
car = car.set_index("car_ID")

# %%
car.tail()
# Out:
#         symboling          CarName fueltype aspiration doornumber carbody  \
# car_ID
# 201            -1  volvo 145e (sw)      gas        std       four   sedan
# 202            -1      volvo 144ea      gas      turbo       four   sedan
# 203            -1      volvo 244dl      gas        std       four   sedan
# 204            -1        volvo 246   diesel      turbo       four   sedan
# 205            -1      volvo 264gl      gas      turbo       four   sedan
#
#        drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# car_ID                                                  ...
# 201           rwd          front      109.1      188.8  ...         141
# 202           rwd          front      109.1      188.8  ...         141
# 203           rwd          front      109.1      188.8  ...         173
# 204           rwd          front      109.1      188.8  ...         145
# 205           rwd          front      109.1      188.8  ...         141
#
# ...

# %%
# car.isnull().sum()
null_per = car.isnull().sum()/car.shape[0]*100
null_per
# Out:
# symboling           0.0
# CarName             0.0
# fueltype            0.0
# aspiration          0.0
# doornumber          0.0
# carbody             0.0
# drivewheel          0.0
# enginelocation      0.0
# wheelbase           0.0
# carlength           0.0
# carwidth            0.0
# carheight           0.0
# curbweight          0.0
# enginetype          0.0
# cylindernumber      0.0
# enginesize          0.0
# fuelsystem          0.0
# boreratio           0.0
# stroke              0.0
# compressionratio    0.0
# horsepower          0.0
# peakrpm             0.0
# citympg             0.0
# highwaympg          0.0
# price               0.0
# dtype: float64

# %%
for i in car.columns:
    print(i + "\t" + str(len(car[i].unique())))
# Out:
# symboling	6
# CarName	147
# fueltype	2
# aspiration	2
# doornumber	2
# carbody	5
# drivewheel	3
# enginelocation	2
# wheelbase	53
# carlength	75
# carwidth	44
# carheight	49
# curbweight	171
# enginetype	7
# cylindernumber	7
# enginesize	44
# fuelsystem	8
# boreratio	38
# stroke	37
# compressionratio	32
# horsepower	59
# peakrpm	23
# citympg	29
# highwaympg	30
# price	189

# %%
for i in car.columns:
    print("unique value of {}: ({})\n{}\n".format(i, len(car[i].unique()),car[i].unique))
# Out:
# unique value of symboling: (6)
# <bound method Series.unique of car_ID
# 1      3
# 2      3
# 3      1
# 4      2
# 5      2
#       ..
# 201   -1
# 202   -1
# 203   -1
# 204   -1
# 205   -1
# Name: symboling, Length: 205, dtype: int64>
#
# unique value of CarName: (147)
# <bound method Series.unique of car_ID
# 1            alfa-romero giulia
# 2           alfa-romero stelvio
# 3      alfa-romero Quadrifoglio
# 4                   audi 100 ls
# 5                    audi 100ls
#                  ...
# 201             volvo 145e (sw)
# 202                 volvo 144ea
# 203                 volvo 244dl
# 204                   volvo 246
# 205                 volvo 264gl
# Name: CarName, Length: 205, dtype: object>
#
# unique value of fueltype: (2)
# <bound method Series.unique of car_ID
# 1         gas
# 2         gas
# 3         gas
# 4         gas
# 5         gas
#         ...
# 201       gas
# 202       gas
# 203       gas
# 204    diesel
# 205       gas
# ...

# %%
# Describe the target 
car["price"].describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,8))
graph = sns.distplot(car["price"])
graph.legend(["Skewness: {:.2f}".format(car['price'].skew())])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# create a figure with a size of 25x25 for getting the correlation
plt.figure(figsize=(25,25))

# create a heatmap of the correlation matrix using the "coolwarm" colormap
# and annotate each cell with the correlation coefficient
# The annot=True parameter adds the correlation coefficients to each cell of the heatmap
ax = sns.heatmap(car.corr(), cmap = "coolwarm", annot=True, linewidth=2)

# red : positive correlation,
# blue : negative correlation
# white : no

# %%
# create a correlation matrix of the "train" DataFrame
hig_corr = car.corr()

# identify the features that have a correlation coefficient with "SalePrice"
# that is greater than or equal to 0.5
hig_corr_features = hig_corr.index[abs(hig_corr["price"]) >= 0.5]
hig_corr_features
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginesize',
#        'boreratio', 'horsepower', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
plt.figure(figsize=(12,10))
ax = sns.heatmap(car[hig_corr_features].corr(), cmap='coolwarm',annot=True,linewidth=3)

# %%
car = car[hig_corr_features]

# %%
car.head()
# Out:
#         wheelbase  carlength  carwidth  curbweight  enginesize  boreratio  \
# car_ID
# 1            88.6      168.8      64.1        2548         130       3.47
# 2            88.6      168.8      64.1        2548         130       3.47
# 3            94.5      171.2      65.5        2823         152       2.68
# 4            99.8      176.6      66.2        2337         109       3.19
# 5            99.4      176.6      66.4        2824         136       3.19
#
#         horsepower  citympg  highwaympg    price
# car_ID
# 1              111       21          27  13495.0
# 2              111       21          27  16500.0
# 3              154       19          26  16500.0
# 4              102       24          30  13950.0
# 5              115       18          22  17450.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(car.iloc[:, :-1], 
                                                    car.iloc[:, -1], 
                                                    test_size = 0.3, 
                                                    random_state = 42)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143 entries, 178 to 103
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   wheelbase   143 non-null    float64
#  1   carlength   143 non-null    float64
#  2   carwidth    143 non-null    float64
#  3   curbweight  143 non-null    int64
#  4   enginesize  143 non-null    int64
#  5   boreratio   143 non-null    float64
#  6   horsepower  143 non-null    int64
#  7   citympg     143 non-null    int64
#  8   highwaympg  143 non-null    int64
# dtypes: float64(4), int64(5)
# memory usage: 11.2 KB

# %%
standardScaler = StandardScaler()
standardScaler.fit(X_train)
X_train = standardScaler.transform(X_train)
X_test = standardScaler.transform(X_test)

# %%
linearRegression = LinearRegression()
linearRegression.fit(X_train, y_train)
y_pred = linearRegression.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.7649812490311774

# %%
rf = RandomForestRegressor(n_estimators = 100)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.9428380936598747
